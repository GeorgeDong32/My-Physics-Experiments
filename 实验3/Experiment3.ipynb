# %% [markdown]
# # 实验3-电路设计基础
# > Copyright(c) 2022 GeorgeDong32. All Rights Reserved.

# %%
from cProfile import label
import scipy.constants as cst 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# plt防止中文乱码
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 钨丝灯的伏安特性曲线

# %%
Tdata = pd.read_csv("Tungsten.csv")
U_T = Tdata.iloc[:,0]
I_T = Tdata.iloc[:,1]
R_T = (U_T / I_T)*1000
# print(R_T)
plt.figure(dpi=150)
plt.plot(I_T,U_T)
plt.title("钨丝灯伏安特性曲线")
plt.xlabel("$I(mA)$")
plt.ylabel("U(v)")
plt.savefig("TungstenUI.png")

# %% [markdown]
# ## 测量二极管反向伏安特性

# %%
Ddata = pd.read_csv("DiodeUI.csv")
UN = Ddata.iloc[:,0]
IN = Ddata.iloc[:,1]
UW = Ddata.iloc[:,2]
IW = Ddata.iloc[:,3]
UN = -UN
IN = -IN
UW = -UW
IW = -IW
plt.figure(dpi=150)
plt.xlim(-9,3)
plt.ylim(-30,3)
plt.plot(UW,IW,label="外接法")
plt.plot(UN,IN,label="内接法")
plt.title("稳压二极管反向伏安特性曲线")
plt.xlabel("U/V")
plt.ylabel("I/mA")

ax = plt.gca()                                            # get current axis 获得坐标轴对象
 
ax.spines['left'].set_color('none') 
ax.spines['top'].set_color('none')         # 将右边 上边的两条边颜色设置为空 其实就相当于抹掉这两条边
 
ax.xaxis.set_ticks_position('bottom')   
ax.yaxis.set_ticks_position('right')          # 指定下边的边作为 x 轴   指定左边的边为 y 轴
 
ax.spines['bottom'].set_position(('data', 0))   #指定 data  设置的bottom(也就是指定的x轴)绑定到y轴的0这个点上

plt.savefig("DiodeUI.png")
